# %% [markdown]
# First SQL query

# %%
select * FROM users
# Out:
#          id first_name last_name                     email  \
# 0    465987    Kaitlyn   Hermann      kaitlyn@wearcade.com
# 1    476773    Lucinda   Zboncak       lucinda@snoodle.com
# 2    478060    Desiree     Beier       desiree@lagerly.com
# 3    511551      Colby  StrosinI      colby@cookbright.com
# 4    513312  Elizabeth  BarrowsI  elizabeth@cookbright.com
# ..      ...        ...       ...                       ...
# 803  578643    Krystal     Wyman    krystal@goaerobics.com
# 804  578663       Asia     Boyer        asia@brewmogul.com
# 805  578746      Erica    Wisoky         erica@beerbox.com
# 806  578799    Katlynn      Bode         katlynn@iwire.com
# 807  579011     Carley  Schaefer        carley@getmose.com
#
#              created_at          updated_at  team_id version_number
# 0   2018-05-17 19:14:07 2020-07-23 18:35:08  46100.0         0.11.3
# 1   2018-11-02 18:30:12 2020-07-20 19:17:37  48415.0         0.11.3
# ...
